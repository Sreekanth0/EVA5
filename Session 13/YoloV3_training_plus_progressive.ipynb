# %% [markdown]
# ### Cloned the repository

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 46.94 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %% [markdown]
# ### Uploaded the Custom Dataset

# %%
# !unzip -qq '/content/gdrive/My Drive/EVA5_data/YoloV3_dataset.zip'

# %%
# !mv YoloV3_dataset/ YoloV3/data/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %% [markdown]
# #### First Trained for 150 Epochs on image size 256

# %%
# !python train.py --data data/YoloV3_dataset/custom.data --batch 64 --img-size 256 --cache --cfg cfg/yolov3-custom1.cfg --epochs 150
# Out:
# Namespace(accumulate=4, adam=False, batch_size=64, bucket='', cache_images=True, cfg='cfg/yolov3-custom1.cfg', data='data/YoloV3_dataset/custom.data', device='', epochs=150, evolve=False, img_size=[256], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='/content/gdrive/My Drive/EVA5_data/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-25 12:47:39.977016: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3034 found, 131 missing, 38 empty, 0 duplicate, for 3203 images): 100% 3203/3203 [00:00<00:00, 9109.35it/s]
# Caching images (0.4GB): 100% 3203/3203 [00:17<00:00, 185.99it/s]
# ...

# %%
from utils.utils import *; create_backbone('/content/gdrive/My Drive/EVA5_data/last.pt')

# %% [markdown]
# ### Remaining 150 epochs were run with image size 512

# %%
# !python train.py --data data/YoloV3_dataset/custom.data --batch 16 --img-size 512 --cache --cfg cfg/yolov3-custom1.cfg --epochs 150 --weights weights/backbone.pt
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom1.cfg', data='data/YoloV3_dataset/custom.data', device='', epochs=150, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/backbone.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-25 16:39:36.771342: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3034 found, 131 missing, 38 empty, 0 duplicate, for 3203 images): 100% 3203/3203 [00:00<00:00, 8595.26it/s]
# Caching images (1.8GB): 100% 3203/3203 [00:20<00:00, 152.56it/s]
# ...

# %%
from utils.utils import *; create_backbone('/content/gdrive/My Drive/EVA5_data/last.pt')

# %%
# !python train.py --data data/YoloV3_dataset/custom.data --batch 16 --img-size 512 --cache --cfg cfg/yolov3-custom1.cfg --epochs 100 --weights weights/backbone.pt
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom1.cfg', data='data/YoloV3_dataset/custom.data', device='', epochs=100, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/backbone.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-26 01:13:54.423935: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3034 found, 131 missing, 38 empty, 0 duplicate, for 3203 images): 100% 3203/3203 [00:00<00:00, 8969.88it/s]
# Caching images (1.8GB): 100% 3203/3203 [00:19<00:00, 165.44it/s]
# ...

# %%
from utils.utils import *; create_backbone('/content/gdrive/My Drive/EVA5_data/last.pt')

# %%
# !python train.py --data data/YoloV3_dataset/custom.data --batch 16 --img-size 512 --cache --cfg cfg/yolov3-custom1.cfg --epochs 75 --weights weights/backbone.pt
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-custom1.cfg', data='data/YoloV3_dataset/custom.data', device='', epochs=75, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/backbone.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-26 02:50:44.774771: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3034 found, 131 missing, 38 empty, 0 duplicate, for 3203 images): 100% 3203/3203 [00:00<00:00, 7962.82it/s]
# Caching images (1.8GB): 100% 3203/3203 [00:20<00:00, 154.21it/s]
# ...

# %%
# !mkdir new_imgs

# %% [markdown]
# ### For inference on Video, collecting frames from a video using FFMPEG

# %%
# !ffmpeg -i '/content/new_video.mp4' -vf fps=24 new_imgs/img%03d.jpg
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %% [markdown]
# #### Detecting on all the individual images using the latest saved model & saving them.

# %%
# !python detect.py --cfg 'cfg/yolov3-custom1.cfg' --names 'data/YoloV3_dataset/custom.names' --source 'new_imgs' --conf-thres 0.2 --output new_out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom1.cfg', classes=None, conf_thres=0.2, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/YoloV3_dataset/custom.names', output='new_out_out', save_txt=False, source='new_imgs', view_img=False, weights='/content/gdrive/My Drive/EVA5_data/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/1633 new_imgs/img001.jpg: 320x512 2 vests, Done. (0.033s)
# image 2/1633 new_imgs/img002.jpg: 320x512 2 vests, Done. (0.033s)
# image 3/1633 new_imgs/img003.jpg: 320x512 2 vests, Done. (0.033s)
# image 4/1633 new_imgs/img004.jpg: 320x512 1 vests, Done. (0.033s)
# image 5/1633 new_imgs/img005.jpg: 320x512 1 vests, Done. (0.033s)
# image 6/1633 new_imgs/img006.jpg: 320x512 1 vests, Done. (0.033s)
# image 7/1633 new_imgs/img007.jpg: 320x512 1 vests, Done. (0.028s)
# ...

# %% [markdown]
# #### Used FFMPEG to convert all the output images to make video again

# %%
# !ffmpeg -framerate 24 -i 'new_out_out/img%03d.jpg' new_output.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !cp new_output.mp4 '/content/gdrive/My Drive/EVA5_data/'

# %%
# !mkdir new_imgs_covid

# %%
# !ffmpeg -i '/content/COVID.mp4' -vf fps=24 new_imgs_covid/img%05d.jpg
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !python detect.py --cfg 'cfg/yolov3-custom1.cfg' --names 'data/YoloV3_dataset/custom.names' --source 'new_imgs_covid' --conf-thres 0.2 --output new_out_out_covid
# Out:
# Streaming output truncated to the last 5000 lines.
# image 822/5818 new_imgs_covid/img00822.jpg: 320x512 1 vests, Done. (0.016s)
# image 823/5818 new_imgs_covid/img00823.jpg: 320x512 1 vests, Done. (0.016s)
# image 824/5818 new_imgs_covid/img00824.jpg: 320x512 1 vests, Done. (0.016s)
# image 825/5818 new_imgs_covid/img00825.jpg: 320x512 1 vests, Done. (0.016s)
# image 826/5818 new_imgs_covid/img00826.jpg: 320x512 1 vests, Done. (0.016s)
# image 827/5818 new_imgs_covid/img00827.jpg: 320x512 1 vests, Done. (0.016s)
# image 828/5818 new_imgs_covid/img00828.jpg: 320x512 1 vests, Done. (0.016s)
# image 829/5818 new_imgs_covid/img00829.jpg: 320x512 1 vests, Done. (0.016s)
# image 830/5818 new_imgs_covid/img00830.jpg: 320x512 1 vests, Done. (0.016s)
# image 831/5818 new_imgs_covid/img00831.jpg: 320x512 1 vests, Done. (0.016s)
# image 832/5818 new_imgs_covid/img00832.jpg: 320x512 1 vests, Done. (0.016s)
# image 833/5818 new_imgs_covid/img00833.jpg: 320x512 1 vests, Done. (0.016s)
# ...

# %%
# !ffmpeg -framerate 24 -i 'new_out_out_covid/img%05d.jpg' new_output_covid.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !cp new_output_covid.mp4 '/content/gdrive/My Drive/EVA5_data/'
